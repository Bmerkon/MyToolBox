# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"></ul></div>

# %%
from bmerkon_toolbox.factor.factors import database_factors
from bmerkon_toolbox.factor.update import load_names_f,update_factors
from bmerkon_toolbox.factor.factors.database_factors_params import factor_list,factor_params

# %%
last_day='2018-05-17'
#%%
for ifactor in factor_params:
    if 'params' in factor_params[ifactor]:
        if ('last_day' in factor_params[ifactor]['params']) and (factor_params[ifactor]['params']['last_day'] is None):
            factor_params[ifactor]['params']['last_day']=last_day

# %%
factor_list_select=factor_list
#factordaily()
update_factors(factor_list_select,factor_params,database_factors,last_day)
# Out:
# tradingday
# 0.03298616409301758
# stockinfo
# 0.05798220634460449
# PrevClosePrice
# 62.637004137039185
# OpenPrice
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-4493f79ebb3e> in <module>()
#       1 factor_list_select=factor_list
#       2 #factordaily()
# ----> 3 update_factors(factor_list_select,factor_params,database_factors,last_day)
#
# C:\ProgramData\Anaconda3\envs\finance\lib\site-packages\bmerkon_toolbox-0.1-py3.5.egg\bmerkon_toolbox\factor\update.py in update_factors(factor_list, factor_params, customfactor, last_day, init, new_start_str)
#     175             # 11. 存储
#     176             all_fv=pd.DataFrame(index=tradingday,columns=code,data=np.nan)
# --> 177             all_fv.update(old_fv)
#     178             all_fv.update(new_fv[new_fv.index>=new_startday],overwrite=True)
#     179             my_save(all_fv,fullpath)
#
# ...

# %%
data=load_names_f(['PrevClosePrice'])
data['PrevClosePrice'].tail()
# Out:
# SecuCode    000001 000002  000003 000004 000005 000006 000007 000008 000009  \
# TradingDate
# 2018-05-11   11.01  28.07     NaN  21.95   3.75   7.56   13.6   5.74   6.08
# 2018-05-14   11.01  27.94     NaN  21.62   3.76    7.5  13.49   5.66   6.11
# 2018-05-15   11.18  27.94     NaN  21.45   3.75   7.31  13.47    5.6   6.11
# 2018-05-16   11.12  27.75     NaN  21.43   3.72   7.43   13.4   5.78   6.17
# 2018-05-17    10.9  27.23     NaN  22.09    3.7   7.44   13.3   5.91   6.12
#
# SecuCode    000010  ...   300716 600933  300736 603045  603348 001965 603712  \
# TradingDate         ...
# 2018-05-11    3.76  ...     28.8  13.54   46.54    NaN   43.12   8.59  35.64
# 2018-05-14    3.74  ...    28.89  13.36   45.13    NaN   41.88   8.47  35.93
# 2018-05-15     3.7  ...    28.76  13.17   43.98    NaN   43.24   8.46  37.17
# 2018-05-16    3.73  ...     29.5  14.02   46.83    NaN   47.56   8.76  37.56
# 2018-05-17    3.92  ...    28.87  13.81   47.35   9.65   45.36   8.65  36.52
#
# ...
