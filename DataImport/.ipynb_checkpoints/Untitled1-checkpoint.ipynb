# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"></ul></div>

# %%
from WindPy import w
first_day='2015-01-01'
last_day='2017-08-01'
w.start()
p_wind=w.wsd('000001.SZ','close',first_day,last_day,'PriceAdj=f')

# %%
import sys
sys.path.append('C:\Wind\Wind.NET.Client\WindNET\bin')

# %%
import MDDB
import pandas as pd
import numpy as np

MDB=MDDB.MDDB()

# %%
f2=open('testsql2.sql')
sql2=f2.read()

# %%
data=pd.read_sql(sql2,MDB.conn)

# %%
data.head(5)
# Out:
#                    datetime  ticker    open    high     low   close  volume  \
# 0 2017-03-01 01:00:00+00:00  rb1703  3800.0  3800.0  3800.0  3800.0     540
# 1 2017-03-01 01:17:00+00:00  rb1703  3701.0  3701.0  3701.0  3701.0      60
# 2 2017-03-01 01:39:00+00:00  rb1703  3710.0  3710.0  3710.0  3710.0      60
# 3 2017-03-01 02:30:00+00:00  rb1703  3710.0  3862.0  3710.0  3862.0      60
# 4 2017-03-01 03:19:00+00:00  rb1703  3800.0  3800.0  3800.0  3800.0      60
#
#    openinterest month year_end  rank
# 0          1740    03        7    15
# 1          1680    03        7    15
# 2          1620    03        7    15
# 3          1620    03        7    15
# 4          1560    03        7    15

# %%
import numpy as np
data['month']=data['ticker'].str.slice(start=4)
data['year_end']=data['ticker'].str.slice(start=3,stop=4)
data=data[data['year_end'].str.isnumeric()]
data['rank']=data['month'].astype(int).values+np.mod(data['year_end'].astype(int).values,2)*12

# %%
dp=data.pivot_table(index='datetime',columns='rank',values='open')

# %%
import datetime
a.ix[a.index.indexer_between_time(datetime.time(10), datetime.time(14))]
# Out:
# rank                           1       2   3       4       5       6       7   \
# datetime
# 2017-03-01 10:00:00+00:00     NaN     NaN NaN     NaN     NaN     NaN     NaN
# 2017-03-01 10:01:00+00:00     NaN     NaN NaN     NaN     NaN     NaN     NaN
# 2017-03-01 10:02:00+00:00     NaN     NaN NaN     NaN     NaN     NaN     NaN
# 2017-03-01 10:03:00+00:00     NaN     NaN NaN     NaN     NaN     NaN     NaN
# 2017-03-01 10:04:00+00:00     NaN     NaN NaN     NaN     NaN     NaN     NaN
# 2017-03-01 10:05:00+00:00     NaN     NaN NaN     NaN     NaN     NaN     NaN
# 2017-03-01 10:06:00+00:00     NaN     NaN NaN     NaN     NaN     NaN     NaN
# 2017-03-01 10:07:00+00:00     NaN     NaN NaN     NaN     NaN     NaN     NaN
# 2017-03-01 10:08:00+00:00     NaN     NaN NaN     NaN     NaN     NaN     NaN
# 2017-03-01 10:09:00+00:00     NaN     NaN NaN     NaN     NaN     NaN     NaN
# 2017-03-01 10:10:00+00:00     NaN     NaN NaN     NaN     NaN     NaN     NaN
# ...

# %%
b=a.index.indexer_between_time(datetime.time(10), datetime.time(14))

# %%
b
# Out:
# array([   540,    541,    542, ..., 293098, 293099, 293100], dtype=int64)

# %%
a=dp.resample('1min').agg('last')

# %%
a.shape
# Out:
# (294121, 19)

# %%
dp.shape
# Out:
# (48071, 19)

# %%
help(dp.resample)
# Out:
# Help on method resample in module pandas.core.generic:
#
# resample(rule, how=None, axis=0, fill_method=None, closed=None, label=None, convention='start', kind=None, loffset=None, limit=None, base=0, on=None, level=None) method of pandas.core.frame.DataFrame instance
#     Convenience method for frequency conversion and resampling of time
#     series.  Object must have a datetime-like index (DatetimeIndex,
#     PeriodIndex, or TimedeltaIndex), or pass datetime-like values
#     to the on or level keyword.
#
#     Parameters
#     ----------
#     rule : string
#         the offset string or object representing target conversion
#     axis : int, optional, default 0
#     closed : {'right', 'left'}
#         Which side of bin interval is closed
#     label : {'right', 'left'}
#         Which bin edge label to label bucket with
#     convention : {'start', 'end', 's', 'e'}
#     loffset : timedelta
#         Adjust the resampled time labels
#     base : int, default 0
# ...

# %%
help(a.str.slice)
# Out:
# Help on method slice in module pandas.core.strings:
#
# slice(start=None, stop=None, step=None) method of pandas.core.strings.StringMethods instance
#     Slice substrings from each element in the Series/Index
#
#     Parameters
#     ----------
#     start : int or None
#     stop : int or None
#     step : int or None
#
#     Returns
#     -------
#     sliced : Series/Index of objects

# %%
data.shape
# Out:
# (208913, 8)

# %%
f1=open('testsql.sql')
sql1=f1.read()

# %%
data1=pd.read_sql(sql1,MDB.conn)

# %%
data1.head(5)
# Out:
#          date ticker    open    high     low   close  settle  volume  \
# 0  2017-02-20  a1703  4232.0  4232.0  4200.0  4200.0  4217.0      18
# 1  2017-02-20  a1705  4230.0  4251.0  4214.0  4236.0  4235.0  130384
# 2  2017-02-20  a1707     0.0     0.0     0.0  4253.0  4253.0       0
# 3  2017-02-20  a1709  4221.0  4221.0  4180.0  4200.0  4198.0   19624
# 4  2017-02-20  a1711  4198.0  4198.0  4198.0  4198.0  4198.0       2
#
#    openinterest
# 0          1246
# 1        164596
# 2            28
# 3         49522
# 4             4

# %%
import matlab
